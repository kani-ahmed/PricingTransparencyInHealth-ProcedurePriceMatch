# %%
import os
import json

def get_key_names(json_file):
    with open(json_file, 'r') as f:
        try:
            data = json.load(f)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON in file {json_file}: {e}")
            return None
        
        if isinstance(data, list):
            # If JSON is an array, take keys from the first object
            if data:
                return set(data[0].keys())
            else:
                return set()
        else:
            # If JSON is an object, take keys directly
            return set(data.keys())



def main(folder_path):
    files = os.listdir(folder_path)
    file_key_names = {}

    # Iterate through each file
    for file_name in files:
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and file_name.endswith('.json'):
            key_names = get_key_names(file_path)
            file_key_names[file_name] = key_names
    
    # Find files with same key names
    same_key_names = {}
    for file1, keys1 in file_key_names.items():
        for file2, keys2 in file_key_names.items():
            if file1 != file2 and keys1 == keys2:
                same_key_names[file1] = file2
    
    # Find files with different filenames
    different_filenames = {}
    for file1 in file_key_names.keys():
        for file2 in file_key_names.keys():
            if file1 != file2 and file_key_names[file1] == file_key_names[file2]:
                different_filenames[file1] = file2
    
    print("Files with same key names:")
    for file1, file2 in same_key_names.items():
        print(f"{file1} and {file2}")

    print("\nFiles with different filenames but same key names:")
    for file1, file2 in different_filenames.items():
        print(f"{file1} and {file2}")

if __name__ == "__main__":
    folder_path = r"C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files"

    main(folder_path)
# Out:
# Error decoding JSON in file C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files\340753531_Southwest-General-Hospital_standardcharges.json: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON in file C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files\PriceTransparency-Toledo.json: Expecting value: line 1 column 1 (char 0)
# Files with same key names:
# 1356366991_aultman-hospital_standardcharges.json and 341407259_mary-rutan-hospital_standardcharges-2.json
# 1891718375_aultman-orrville-hospital_standardcharges.json and 341407259_mary-rutan-hospital_standardcharges-2.json
# 1942385794_alliance-community-hospital_standardcharges.json and 341407259_mary-rutan-hospital_standardcharges-2.json
# 261375072_summa-health-system_standardcharges.json and 261375072_summa-health-system_standardcharges_2.json
# 261375072_summa-health-system_standardcharges_1.json and 261375072_summa-health-system_standardcharges_2.json
# ...

# %%
import os
import json

def get_key_names(json_file):
    with open(json_file, 'r') as f:
        try:
            data = json.load(f)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON in file {json_file}: {e}")
            return None
        
        if isinstance(data, list):
            # If JSON is an array, take keys from the first object
            if data:
                return set(data[0].keys())
            else:
                return set()
        else:
            # If JSON is an object, take keys directly
            return set(data.keys())

def main(folder_path):
    try:
        files = os.listdir(folder_path)
    except PermissionError as e:
        print(f"Permission denied while accessing {folder_path}: {e}")
        return
    
    file_key_names = {}

    # Iterate through each file
    for file_name in files:
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and file_name.endswith('.json'):
            key_names = get_key_names(file_path)
            if key_names is not None:
                file_key_names[file_name] = key_names
    
    # Find files with same key names
    same_key_names = {}
    for file1, keys1 in file_key_names.items():
        for file2, keys2 in file_key_names.items():
            if file1 != file2 and keys1 == keys2:
                same_key_names[file1] = file2
    
    # Find files with different filenames but same key names
    different_filenames = {}
    for file1 in file_key_names.keys():
        for file2 in file_key_names.keys():
            if file1 != file2 and file_key_names[file1] == file_key_names[file2]:
                different_filenames[file1] = file2
    
    print("Files with same key names:")
    for file1, file2 in same_key_names.items():
        print(f"{file1} and {file2}")

    print("\nFiles with different filenames but same key names:")
    for file1, file2 in different_filenames.items():
        print(f"{file1} and {file2}")

if __name__ == "__main__":
    folder_path = r"C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files"

    main(folder_path)
# Out:
# Error decoding JSON in file C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files\340753531_Southwest-General-Hospital_standardcharges.json: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON in file C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files\PriceTransparency-Toledo.json: Expecting value: line 1 column 1 (char 0)
# Files with same key names:
# 1356366991_aultman-hospital_standardcharges.json and 341407259_mary-rutan-hospital_standardcharges-2.json
# 1891718375_aultman-orrville-hospital_standardcharges.json and 341407259_mary-rutan-hospital_standardcharges-2.json
# 1942385794_alliance-community-hospital_standardcharges.json and 341407259_mary-rutan-hospital_standardcharges-2.json
# 261375072_summa-health-system_standardcharges.json and 261375072_summa-health-system_standardcharges_2.json
# 261375072_summa-health-system_standardcharges_1.json and 261375072_summa-health-system_standardcharges_2.json
# ...

# %%
import os
import json

def get_key_names(json_file):
    with open(json_file, 'r') as f:
        try:
            data = json.load(f)
        except (json.JSONDecodeError, UnicodeDecodeError) as e:
            print(f"Error decoding JSON in file {json_file}: {e}")
            return None
        
        if isinstance(data, list):
            # If JSON is an array, take keys from the first object
            if data:
                return set(data[0].keys())
            else:
                return set()
        else:
            # If JSON is an object, take keys directly
            return set(data.keys())

def main(folder_path):
    files = os.listdir(folder_path)
    file_key_names = {}

    # Iterate through each file
    for file_name in files:
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and file_name.endswith('.json'):
            key_names = get_key_names(file_path)
            if key_names is not None:
                file_key_names[file_name] = key_names
    
    # Print key names for each file
    for file_name, key_names in file_key_names.items():
        print(f"Key names in file {file_name}: {key_names}")
    
    # Find common column names
    common_column_names = set.intersection(*file_key_names.values())
    
    if common_column_names:
        print("\nCommon column names in all JSON files:")
        print(common_column_names)
    else:
        print("\nNo common column names found among JSON files.")

if __name__ == "__main__":
    folder_path = r"C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files"
    main(folder_path)
# Out:
# Error decoding JSON in file C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files\340753531_Southwest-General-Hospital_standardcharges.json: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON in file C:\Users\purru\Desktop\PricingTransparencyInHealth-ProcedurePriceMatch\json-files\PriceTransparency-Toledo.json: Expecting value: line 1 column 1 (char 0)
# Key names in file 1356366991_aultman-hospital_standardcharges.json: {'license_information', 'financial_aid_policy', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'hospital_name'}
# Key names in file 1891718375_aultman-orrville-hospital_standardcharges.json: {'license_information', 'financial_aid_policy', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'hospital_name'}
# ...

# %%
Key names in file 1356366991_aultman-hospital_standardcharges.json: {'license_information', 'financial_aid_policy', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'hospital_name'}
Key names in file 1891718375_aultman-orrville-hospital_standardcharges.json: {'license_information', 'financial_aid_policy', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'hospital_name'}
Key names in file 1942385794_alliance-community-hospital_standardcharges.json: {'license_information', 'financial_aid_policy', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'hospital_name'}
Key names in file 261375072_summa-health-system_standardcharges.json: {'Outpatient Payer Specific Charge 30', 'Outpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 37', 'Outpatient Payer Specific Charge 10', 'Inpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 8', 'Outpatient Payer Specific Charge 2', 'Outpatient Payer Specific Charge 43', 'Outpatient Payer Specific Charge 17', 'Outpatient Payer Specific Charge 23', 'Inpatient Payer Specific Charge 38', 'Outpatient Payer Specific Charge 4', 'Outpatient Payer Specific Charge 26', 'Outpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 31', 'Outpatient Payer Specific Charge 44', 'Supply Charges', 'Outpatient Payer Specific Charge 18', 'Inpatient Payer Specific Charge 26', 'File Summary', 'Inpatient Payer Specific Charge 3', 'Inpatient Payer Specific Charge 4', 'Inpatient Payer Specific Charge 17', 'Outpatient Payer Specific Charge 38', 'Outpatient Payer Specific Charge 40', 'Outpatient Payer Specific Charge 3', 'Outpatient Payer Specific Charge 31', 'Outpatient Payer Specific Charge 20', 'Inpatient Payer Specific Charge 40', 'Outpatient Payer Specific Charge 8', 'Inpatient Payer Specific Charge 30', 'Outpatient Payer Specific Charge 15', 'Inpatient Payer Specific Charge 11', 'Outpatient Payer Specific Charge 19', 'Outpatient Payer Specific Charge 29', 'Outpatient Payer Specific Charge 13', 'Outpatient Payer Specific Charge 11', 'Outpatient Payer Specific Charge 12', 'Inpatient Payer Specific Charge 13', 'Outpatient Payer Specific Charge 33', 'Inpatient Payer Specific Charge 20', 'Outpatient Payer Specific Charge 36', 'Inpatient Payer Specific Charge 12', 'Inpatient Payer Specific Charge 35', 'Inpatient Payer Specific Charge 29', 'Outpatient Payer Specific Charge 21', 'Inpatient Payer Specific Charge 16', 'Outpatient Payer Specific Charge 42', 'Inpatient De-identified Maximum Negotiated Charge', 'Inpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 28', 'Inpatient Payer Specific Charge 34', 'Outpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 19', 'Outpatient Payer Specific Charge 39', 'Inpatient Payer Specific Charge 33', 'Inpatient Payer Specific Charge 23', 'Outpatient Payer Specific Charge 37', 'Outpatient Payer Specific Charge 9', 'Outpatient Payer Specific Charge 6', 'Outpatient De-identified Maximum Negotiated Charge', 'Inpatient De-identified Minimum Negotiated Charge', 'Inpatient Payer Specific Charge 24', 'Inpatient Payer Specific Charge 6', 'Inpatient Payer Specific Charge 39', 'Outpatient De-identified Minimum Negotiated Charge', 'Inpatient Payer Specific Charge 18', 'Outpatient Payer Specific Charge 34', 'Outpatient Payer Specific Charge 24', 'Inpatient Payer Specific Charge 9', 'Outpatient Payer Specific Charge 16', 'Inpatient Payer Specific Charge 22', 'Outpatient Payer Specific Charge 32', 'Discounted Cash Pricing Policy', 'Gross Charges', 'Inpatient Payer Specific Charge 27', 'Inpatient Payer Specific Charge 36', 'Inpatient Payer Specific Charge 21', 'Inpatient Payer Specific Charge 25', 'Inpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 14', 'Inpatient Payer Specific Charge 32', 'Inpatient Payer Specific Charge 15', 'Outpatient Payer Specific Charge 25', 'Inpatient Payer Specific Charge 2', 'Outpatient Payer Specific Charge 27', 'Inpatient Payer Specific Charge 10', 'Outpatient Payer Specific Charge 14', 'Outpatient Payer Specific Charge 35', 'Outpatient Payer Specific Charge 22', 'Outpatient Payer Specific Charge 28', 'Outpatient Payer Specific Charge 41'}
Key names in file 261375072_summa-health-system_standardcharges_1.json: {'Outpatient Payer Specific Charge 30', 'Outpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 37', 'Outpatient Payer Specific Charge 10', 'Inpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 8', 'Outpatient Payer Specific Charge 2', 'Outpatient Payer Specific Charge 43', 'Outpatient Payer Specific Charge 17', 'Outpatient Payer Specific Charge 23', 'Inpatient Payer Specific Charge 38', 'Outpatient Payer Specific Charge 4', 'Outpatient Payer Specific Charge 26', 'Outpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 31', 'Outpatient Payer Specific Charge 44', 'Supply Charges', 'Outpatient Payer Specific Charge 18', 'Inpatient Payer Specific Charge 26', 'File Summary', 'Inpatient Payer Specific Charge 3', 'Inpatient Payer Specific Charge 4', 'Inpatient Payer Specific Charge 17', 'Outpatient Payer Specific Charge 38', 'Outpatient Payer Specific Charge 40', 'Outpatient Payer Specific Charge 3', 'Outpatient Payer Specific Charge 31', 'Outpatient Payer Specific Charge 20', 'Inpatient Payer Specific Charge 40', 'Outpatient Payer Specific Charge 8', 'Inpatient Payer Specific Charge 30', 'Outpatient Payer Specific Charge 15', 'Inpatient Payer Specific Charge 11', 'Outpatient Payer Specific Charge 19', 'Outpatient Payer Specific Charge 29', 'Outpatient Payer Specific Charge 13', 'Outpatient Payer Specific Charge 11', 'Outpatient Payer Specific Charge 12', 'Inpatient Payer Specific Charge 13', 'Outpatient Payer Specific Charge 33', 'Inpatient Payer Specific Charge 20', 'Outpatient Payer Specific Charge 36', 'Inpatient Payer Specific Charge 12', 'Inpatient Payer Specific Charge 35', 'Inpatient Payer Specific Charge 29', 'Outpatient Payer Specific Charge 21', 'Inpatient Payer Specific Charge 16', 'Outpatient Payer Specific Charge 42', 'Inpatient De-identified Maximum Negotiated Charge', 'Inpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 28', 'Inpatient Payer Specific Charge 34', 'Outpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 19', 'Outpatient Payer Specific Charge 39', 'Inpatient Payer Specific Charge 33', 'Inpatient Payer Specific Charge 23', 'Outpatient Payer Specific Charge 37', 'Outpatient Payer Specific Charge 9', 'Outpatient Payer Specific Charge 6', 'Outpatient De-identified Maximum Negotiated Charge', 'Inpatient De-identified Minimum Negotiated Charge', 'Inpatient Payer Specific Charge 24', 'Inpatient Payer Specific Charge 6', 'Inpatient Payer Specific Charge 39', 'Outpatient De-identified Minimum Negotiated Charge', 'Inpatient Payer Specific Charge 18', 'Outpatient Payer Specific Charge 34', 'Outpatient Payer Specific Charge 24', 'Inpatient Payer Specific Charge 9', 'Outpatient Payer Specific Charge 16', 'Inpatient Payer Specific Charge 22', 'Outpatient Payer Specific Charge 32', 'Discounted Cash Pricing Policy', 'Gross Charges', 'Inpatient Payer Specific Charge 27', 'Inpatient Payer Specific Charge 36', 'Inpatient Payer Specific Charge 21', 'Inpatient Payer Specific Charge 25', 'Inpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 14', 'Inpatient Payer Specific Charge 32', 'Inpatient Payer Specific Charge 15', 'Outpatient Payer Specific Charge 25', 'Inpatient Payer Specific Charge 2', 'Outpatient Payer Specific Charge 27', 'Inpatient Payer Specific Charge 10', 'Outpatient Payer Specific Charge 14', 'Outpatient Payer Specific Charge 35', 'Outpatient Payer Specific Charge 22', 'Outpatient Payer Specific Charge 28', 'Outpatient Payer Specific Charge 41'}
Key names in file 261375072_summa-health-system_standardcharges_2.json: {'Outpatient Payer Specific Charge 30', 'Outpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 37', 'Outpatient Payer Specific Charge 10', 'Inpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 8', 'Outpatient Payer Specific Charge 2', 'Outpatient Payer Specific Charge 43', 'Outpatient Payer Specific Charge 17', 'Outpatient Payer Specific Charge 23', 'Inpatient Payer Specific Charge 38', 'Outpatient Payer Specific Charge 4', 'Outpatient Payer Specific Charge 26', 'Outpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 31', 'Outpatient Payer Specific Charge 44', 'Supply Charges', 'Outpatient Payer Specific Charge 18', 'Inpatient Payer Specific Charge 26', 'File Summary', 'Inpatient Payer Specific Charge 3', 'Inpatient Payer Specific Charge 4', 'Inpatient Payer Specific Charge 17', 'Outpatient Payer Specific Charge 38', 'Outpatient Payer Specific Charge 40', 'Outpatient Payer Specific Charge 3', 'Outpatient Payer Specific Charge 31', 'Outpatient Payer Specific Charge 20', 'Inpatient Payer Specific Charge 40', 'Outpatient Payer Specific Charge 8', 'Inpatient Payer Specific Charge 30', 'Outpatient Payer Specific Charge 15', 'Inpatient Payer Specific Charge 11', 'Outpatient Payer Specific Charge 19', 'Outpatient Payer Specific Charge 29', 'Outpatient Payer Specific Charge 13', 'Outpatient Payer Specific Charge 11', 'Outpatient Payer Specific Charge 12', 'Inpatient Payer Specific Charge 13', 'Outpatient Payer Specific Charge 33', 'Inpatient Payer Specific Charge 20', 'Outpatient Payer Specific Charge 36', 'Inpatient Payer Specific Charge 12', 'Inpatient Payer Specific Charge 35', 'Inpatient Payer Specific Charge 29', 'Outpatient Payer Specific Charge 21', 'Inpatient Payer Specific Charge 16', 'Outpatient Payer Specific Charge 42', 'Inpatient De-identified Maximum Negotiated Charge', 'Inpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 28', 'Inpatient Payer Specific Charge 34', 'Outpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 19', 'Outpatient Payer Specific Charge 39', 'Inpatient Payer Specific Charge 33', 'Inpatient Payer Specific Charge 23', 'Outpatient Payer Specific Charge 37', 'Outpatient Payer Specific Charge 9', 'Outpatient Payer Specific Charge 6', 'Outpatient De-identified Maximum Negotiated Charge', 'Inpatient De-identified Minimum Negotiated Charge', 'Inpatient Payer Specific Charge 24', 'Inpatient Payer Specific Charge 6', 'Inpatient Payer Specific Charge 39', 'Outpatient De-identified Minimum Negotiated Charge', 'Inpatient Payer Specific Charge 18', 'Outpatient Payer Specific Charge 34', 'Outpatient Payer Specific Charge 24', 'Inpatient Payer Specific Charge 9', 'Outpatient Payer Specific Charge 16', 'Inpatient Payer Specific Charge 22', 'Outpatient Payer Specific Charge 32', 'Discounted Cash Pricing Policy', 'Gross Charges', 'Inpatient Payer Specific Charge 27', 'Inpatient Payer Specific Charge 36', 'Inpatient Payer Specific Charge 21', 'Inpatient Payer Specific Charge 25', 'Inpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 14', 'Inpatient Payer Specific Charge 32', 'Inpatient Payer Specific Charge 15', 'Outpatient Payer Specific Charge 25', 'Inpatient Payer Specific Charge 2', 'Outpatient Payer Specific Charge 27', 'Inpatient Payer Specific Charge 10', 'Outpatient Payer Specific Charge 14', 'Outpatient Payer Specific Charge 35', 'Outpatient Payer Specific Charge 22', 'Outpatient Payer Specific Charge 28', 'Outpatient Payer Specific Charge 41'}
Key names in file 264827222_uh-ahuja-medical-center_standardcharges.json: {'lastUpdated', 'item'}
Key names in file 270712680_soin-medical-center_standardcharges.json: {'license_information', 'financial_aid_policy', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'hospital_name'}
Key names in file 273633811_clinton-memorial-hospital_standardcharges.json: {'Inpatient De-identified Maximum Negotiated Charge', 'Inpatient Payer Specific Charge 1', 'File Summary', 'Outpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 3', 'Inpatient Payer Specific Charge 4', 'Outpatient Payer Specific Charge 5', 'Outpatient Payer Specific Charge 3', 'Outpatient Payer Specific Charge 10', 'Inpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 8', 'Outpatient Payer Specific Charge 2', 'Inpatient Payer Specific Charge 7', 'Outpatient Payer Specific Charge 8', 'Inpatient Payer Specific Charge 11', 'Outpatient Payer Specific Charge 9', 'Inpatient Payer Specific Charge 2', 'Outpatient Payer Specific Charge 6', 'Outpatient Payer Specific Charge 11', 'Outpatient De-identified Maximum Negotiated Charge', 'Inpatient De-identified Minimum Negotiated Charge', 'Outpatient Payer Specific Charge 4', 'Inpatient Payer Specific Charge 6', 'Outpatient De-identified Minimum Negotiated Charge', 'Outpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 10', 'Inpatient Payer Specific Charge
MANAGED MEDICARE  OP', 'PARAMOUNT  OP', 'AETNA  OP', 'OHIO HEALTH CHOICE  OP', 'SEORMC  IP', 'UHC MANAGED MEDICAID  IP', 'HUMANA  OP', 'BEECHSTREET  OP', 'THE HEALTH PLAN  IP', 'Procedure Description', 'HEALTHREACH  OP', 'COFINITY  OP', 'Quantity', 'AHPO  OP', 'BUCKEYE COMMUNITY PLAN  IP', 'MEDICARE PFFS  OP', 'EMERALD  OP', 'OSU  OP', 'GREATWEST  IP', 'Code Type', 'ANTHEM MANAGED MEDICARE  IP', 'BUCKEYE COMMUNITY PLAN  OP', 'Code', 'GREATWEST  OP', 'UHC MANAGED MEDICARE  OP', 'DEFINITY HEALTH  OP', 'MEDICARE PFFS  IP', 'AETNA MANAGED MEDICAID  OP', 'UHC MANAGED MEDICARE  IP', 'Max OP', 'CIGNA  OP', 'EMERALD  IP', 'OHIO PREFERRED NETWORK  OP', 'BUCKEYE MANAGED MEDICARE  OP', 'PARAMOUNT MANAGED MEDICAID  OP', 'INHEALTH MUTUAL  IP', '<Self-pay> OP'}
Key names in file 31-4394942_grant_standardcharges.json: {'UHC MANAGED MEDICAID IP', 'CARESOURCE MANAGED MEDICAID IP', 'IHG OP', 'UHC IP', 'DEFINITY HEALTH IP', '<Self-pay> IP', 'AETNA IP', 'INHEALTH MUTUAL OP', 'UMWA MANAGED MEDICARE IP', 'UMWA MANAGED MEDICARE OP', 'FLORA IP', 'HUMANA OP', 'COFINITY OP', 'OSU OP', 'MANAGED MEDICAID IP', 'HEALTHLINK OP', 'MOLINA MANAGED MEDICAID IP', 'PARAMOUNT MANAGED MEDICAID OP', 'MMO MANAGED MEDICARE OP', 'HUMANA MANAGED MEDICARE OP', 'HUMANA MANAGED MEDICARE IP', 'HEALTHSMART IP', 'Max IP', 'PARAMOUNT MANAGED MEDICAID IP', 'AETNA MANAGED MEDICAID IP', 'HEALTHREACH IP', 'OSU IP', 'PARAMOUNT IP', 'AETNA MANAGED MEDICAID OP', 'BEECHSTREET OP', 'AHPO IP', 'BUCKEYE COMMUNITY PLAN OP', 'PARAMOUNT OP', 'CARESOURCE MANAGED MEDICARE OP', 'MMO OP', 'AETNA MANAGED MEDICARE IP', 'FIRST HEALTH IP', 'EMERALD IP', 'CARESOURCE MANAGED MEDICARE IP', 'AETNA MANAGED MEDICARE OP', 'CIGNA OP', 'BUCKEYE MANAGED MEDICARE OP', 'MEDIGOLD MANAGED MEDICARE OP', 'MANAGED MEDICAID OP', 'CIGNA IP', 'HUMANA IP', 'IHG IP', 'MEDICARE PFFS IP', 'OP Price', 'UHC OP', 'UHC MANAGED MEDICAID OP', 'SEORMC IP', 'ANTHEM IP', 'COFINITY IP', 'MOLINA MANAGED MEDICARE IP', 'OHIOHEALTHY MEDICAL PLAN OP', 'HEALTHSMART OP', 'MOLINA MANAGED MEDICARE OP', 'GREATWEST OP', 'DEFINITY HEALTH OP', 'COVENTRY OP', 'BUCKEYE MANAGED MEDICARE IP', 'HEALTHLINK IP', 'SEORMC OP', 'OHIO HEALTH CHOICE IP', 'OHIO HEALTH CHOICE OP', 'Min IP', 'CARESOURCE MANAGED MEDICAID OP', 'FIRST HEALTH OP', 'Min OP', 'FLORA OP', 'Rev Code', 'UHC MANAGED MEDICARE OP', 'OHIO PREFERRED NETWORK OP', 'IP Price', 'AETNA OP', 'UHC MANAGED MEDICARE IP', 'Procedure Description', 'Quantity', 'ANTHEM MANAGED MEDICARE IP', 'HEALTHREACH OP', 'AHPO OP', 'INHEALTH MUTUAL IP', 'COVENTRY IP', 'Code Type', 'EMERALD OP', 'GREATWEST IP', 'Code', 'OHIOHEALTHY MEDICAL PLAN IP', 'ANTHEM MANAGED MEDICARE OP', 'MEDICARE PFFS OP', 'Max OP', 'MMO IP', 'MEDIGOLD MANAGED MEDICARE IP', 'MOLINA MANAGED MEDICAID OP', 'THE HEALTH PLAN OP', 'ANTHEM OP', 'OHIO PREFERRED NETWORK IP', 'BEECHSTREET IP', 'MMO MANAGED MEDICARE IP', 'THE HEALTH PLAN IP', '<Self-pay> OP', 'BUCKEYE COMMUNITY PLAN IP'}
Key names in file 31-4394942_grove-city_standardcharges.json: {'MOLINA MANAGED MEDICAID  OP', 'UHC  OP', 'MMO  OP', 'BUCKEYE MANAGED MEDICARE  IP', 'HEALTHSMART  OP', 'UMWA MANAGED MEDICARE  IP', 'COVENTRY  IP', 'MEDIGOLD MANAGED MEDICARE  IP', 'IHG OP', '<Self-pay> IP', 'AETNA IP', 'THE HEALTH PLAN  OP', 'HEALTHLINK  OP', 'CARESOURCE MANAGED MEDICAID  OP', 'MANAGED MEDICAID IP', 'OHIO HEALTH CHOICE  IP', 'ANTHEM  OP', 'MMO MANAGED MEDICARE OP', 'COFINITY  IP', 'HUMANA MANAGED MEDICARE  IP', 'Max IP', 'HEALTHREACH IP', 'CARESOURCE MANAGED MEDICAID  IP', 'PARAMOUNT OP', 'AETNA MANAGED MEDICARE  OP', 'FIRST HEALTH  IP', 'OHIO PREFERRED NETWORK  IP', 'PARAMOUNT MANAGED MEDICAID  IP', 'OHIOHEALTHY MEDICAL PLAN  IP', 'FIRST HEALTH  OP', 'COVENTRY  OP', 'CARESOURCE MANAGED MEDICARE  IP', 'AETNA MANAGED MEDICAID  IP', 'PARAMOUNT  IP', 'FLORA  OP', 'MOLINA MANAGED MEDICARE  IP', 'CARESOURCE MANAGED MEDICARE  OP', 'MOLINA MANAGED MEDICARE  OP', 'AETNA MANAGED MEDICARE  IP', 'HUMANA IP', 'FLORA  IP', 'MEDICARE PFFS IP', 'OP Price', 'ANTHEM  IP', 'AHPO  IP', 'UHC  IP', 'OSU  IP', 'DEFINITY HEALTH  IP', 'HUMANA MANAGED MEDICARE  OP', 'MMO  IP', 'INHEALTH MUTUAL  OP', 'BEECHSTREET  IP', 'HEALTHLINK  IP', 'MEDIGOLD MANAGED MEDICARE  OP', 'HEALTHSMART  IP', 'MMO MANAGED MEDICARE  IP', 'CIGNA  IP', 'IHG  IP', 'SEORMC OP', 'OHIOHEALTHY MEDICAL PLAN  OP', 'Min IP', 'UHC MANAGED MEDICAID  OP', 'MANAGED MEDICAID  OP', 'Min OP', 'MOLINA MANAGED MEDICAID  IP', 'ANTHEM MANAGED MEDICARE  OP', 'Rev Code', 'IP Price', 'UMWA MANAGED MEDICARE  OP', 'AETNA  OP', 'OHIO HEALTH CHOICE  OP', 'SEORMC  IP', 'UHC MANAGED MEDICAID  IP', 'HUMANA  OP', 'BEECHSTREET  OP', 'THE HEALTH PLAN  IP', 'Procedure Description', 'HEALTHREACH  OP', 'COFINITY  OP', 'Quantity', 'AHPO  OP', 'BUCKEYE COMMUNITY PLAN  IP', 'EMERALD  OP', 'OSU  OP', 'GREATWEST  IP', 'Code Type', 'ANTHEM MANAGED MEDICARE  IP', 'BUCKEYE COMMUNITY PLAN  OP', 'Code', 'GREATWEST  OP', 'UHC MANAGED MEDICARE  OP', 'DEFINITY HEALTH  OP', 'MEDICARE PFFS OP', 'AETNA MANAGED MEDICAID  OP', 'UHC MANAGED MEDICARE  IP', 'Max OP', 'CIGNA  OP', 'EMERALD  IP', 'OHIO PREFERRED NETWORK  OP', 'BUCKEYE MANAGED MEDICARE  OP', 'PARAMOUNT MANAGED MEDICAID  OP', 'INHEALTH MUTUAL  IP', '<Self-pay> OP'}
Key names in file 31-4394942_riverside_standardcharges.json: {'MOLINA MANAGED MEDICAID  OP', 'UHC  OP', ' Code', 'MANAGED MEDICAID  IP', 'MMO  OP', 'BUCKEYE MANAGED MEDICARE  IP', 'HEALTHSMART  OP', 'UMWA MANAGED MEDICARE  IP', 'COVENTRY  IP', 'MEDIGOLD MANAGED MEDICARE  IP', 'MMO MANAGED MEDICARE  OP', '<Self-pay> IP', 'THE HEALTH PLAN  OP', 'SEORMC  OP', 'HEALTHLINK  OP', 'CARESOURCE MANAGED MEDICAID  OP', ' Code Type', 'OHIO HEALTH CHOICE  IP', 'ANTHEM  OP', 'AETNA  IP', 'COFINITY  IP', 'HUMANA  IP', ' Min IP', 'HUMANA MANAGED MEDICARE  IP', 'HEALTHREACH  IP', 'IHG  OP', 'CARESOURCE MANAGED MEDICAID  IP', 'AETNA MANAGED MEDICARE  OP', 'FIRST HEALTH  IP', 'OHIO PREFERRED NETWORK  IP', 'PARAMOUNT MANAGED MEDICAID  IP', 'OHIOHEALTHY MEDICAL PLAN  IP', ' Quantity', 'FIRST HEALTH  OP', 'COVENTRY  OP', 'CARESOURCE MANAGED MEDICARE  IP', 'AETNA MANAGED MEDICAID  IP', 'PARAMOUNT  IP', 'FLORA  OP', 'MOLINA MANAGED MEDICARE  IP', 'CARESOURCE MANAGED MEDICARE  OP', 'MOLINA MANAGED MEDICARE  OP', 'AETNA MANAGED MEDICARE  IP', 'FLORA  IP', ' Max OP', 'ANTHEM  IP', 'AHPO  IP', 'UHC  IP', 'OSU  IP', 'DEFINITY HEALTH  IP', 'HUMANA MANAGED MEDICARE  OP', 'MMO  IP', ' Min OP', 'INHEALTH MUTUAL  OP', 'BEECHSTREET  IP', 'HEALTHLINK  IP', 'MEDIGOLD MANAGED MEDICARE  OP', ' OP Price', 'HEALTHSMART  IP', 'MMO MANAGED MEDICARE  IP', 'CIGNA  IP', 'IHG  IP', 'OHIOHEALTHY MEDICAL PLAN  OP', 'UHC MANAGED MEDICAID  OP', 'MANAGED MEDICAID  OP', 'MOLINA MANAGED MEDICAID  IP', ' Rev Code', 'ANTHEM MANAGED MEDICARE  OP', 'UMWA MANAGED MEDICARE  OP', 'PARAMOUNT  OP', 'AETNA  OP', 'OHIO HEALTH CHOICE  OP', 'SEORMC  IP', 'UHC MANAGED MEDICAID  IP', 'HUMANA  OP', 'BEECHSTREET  OP', 'THE HEALTH PLAN  IP', 'HEALTHREACH  OP', 'COFINITY  OP', 'AHPO  OP', 'BUCKEYE COMMUNITY PLAN  IP', 'MEDICARE PFFS  OP', 'EMERALD  OP', 'OSU  OP', 'GREATWEST  IP', 'Effective Date', 'ANTHEM MANAGED MEDICARE  IP', 'BUCKEYE COMMUNITY PLAN  OP', ' Procedure Description', 'GREATWEST  OP', 'UHC MANAGED MEDICARE  OP', 'DEFINITY HEALTH  OP', ' Max IP', ' IP Price', 'MEDICARE PFFS  IP', 'AETNA MANAGED MEDICAID  OP', 'UHC MANAGED MEDICARE  IP', 'CIGNA  OP', 'EMERALD  IP', 'OHIO PREFERRED NETWORK  OP', 'BUCKEYE MANAGED MEDICARE  OP', 'PARAMOUNT MANAGED MEDICAID  OP', 'INHEALTH MUTUAL  IP', '<Self-pay> OP'}
Key names in file 31-4440479-hardin_standardcharges.json: {'MOLINA MANAGED MEDICAID  OP', 'UHC  OP', 'MANAGED MEDICAID  IP', 'MMO  OP', 'BUCKEYE MANAGED MEDICARE  IP', 'HEALTHSMART  OP', 'UMWA MANAGED MEDICARE  IP', 'COVENTRY  IP', 'MEDIGOLD MANAGED MEDICARE  IP', 'MMO MANAGED MEDICARE  OP', '<Self-pay> IP', 'THE HEALTH PLAN  OP', 'SEORMC  OP', 'HEALTHLINK  OP', 'CARESOURCE MANAGED MEDICAID  OP', 'OHIO HEALTH CHOICE  IP', 'ANTHEM  OP', 'AETNA  IP', 'COFINITY  IP', 'HUMANA  IP', 'HUMANA MANAGED MEDICARE  IP', 'HEALTHREACH  IP', 'IHG  OP', 'Max IP', 'CARESOURCE MANAGED MEDICAID  IP', 'AETNA MANAGED MEDICARE  OP', 'FIRST HEALTH  IP', 'OHIO PREFERRED NETWORK  IP', 'PARAMOUNT MANAGED MEDICAID  IP', 'OHIOHEALTHY MEDICAL PLAN  IP', 'FIRST HEALTH  OP', 'COVENTRY  OP', 'CARESOURCE MANAGED MEDICARE  IP', 'AETNA MANAGED MEDICAID  IP', 'PARAMOUNT  IP', 'FLORA  OP', 'MOLINA MANAGED MEDICARE  IP', 'CARESOURCE MANAGED MEDICARE  OP', 'MOLINA MANAGED MEDICARE  OP', 'AETNA MANAGED MEDICARE  IP', 'FLORA  IP', 'OP Price', 'ANTHEM  IP', 'AHPO  IP', 'UHC  IP', 'OSU  IP', 'DEFINITY HEALTH  IP', 'HUMANA MANAGED MEDICARE  OP', 'MMO  IP', 'INHEALTH MUTUAL  OP', 'BEECHSTREET  IP', 'HEALTHLINK  IP', 'MEDIGOLD MANAGED MEDICARE  OP', 'HEALTHSMART  IP', 'MMO MANAGED MEDICARE  IP', 'CIGNA  IP', 'IHG  IP', 'OHIOHEALTHY MEDICAL PLAN  OP', 'Min IP', 'UHC MANAGED MEDICAID  OP', 'MANAGED MEDICAID  OP', 'Min OP', 'MOLINA MANAGED MEDICAID  IP', 'ANTHEM MANAGED MEDICARE  OP', 'Rev Code', 'IP Price', 'UMWA MANAGED MEDICARE  OP', 'PARAMOUNT  OP', 'AETNA  OP', 'OHIO HEALTH CHOICE  OP', 'SEORMC  IP', 'UHC MANAGED MEDICAID  IP', 'HUMANA  OP', 'BEECHSTREET  OP', 'THE HEALTH PLAN  IP', 'Procedure Description', 'HEALTHREACH  OP', 'COFINITY  OP', 'Quantity', 'AHPO  OP', 'BUCKEYE COMMUNITY PLAN  IP', 'MEDICARE PFFS  OP', 'EMERALD  OP', 'OSU  OP', 'GREATWEST  IP', 'Code Type', 'ANTHEM MANAGED MEDICARE  IP', 'BUCKEYE COMMUNITY PLAN  OP', 'Code', 'GREATWEST  OP', 'UHC MANAGED MEDICARE  OP', 'DEFINITY HEALTH  OP', 'MEDICARE PFFS  IP', 'AETNA MANAGED MEDICAID  OP', 'UHC MANAGED MEDICARE  IP', 'Max OP', 'CIGNA  OP', 'EMERALD  IP', 'OHIO PREFERRED NETWORK  OP', 'BUCKEYE MANAGED MEDICARE  OP', 'PARAMOUNT MANAGED MEDICAID  OP', 'INHEALTH MUTUAL  IP', '<Self-pay> OP'}
Key names in file 31-4446959_obleness_standardcharges.json: {'MOLINA MANAGED MEDICAID  OP', 'UHC  OP', 'MANAGED MEDICAID  IP', 'MMO  OP', 'BUCKEYE MANAGED MEDICARE  IP', 'HEALTHSMART  OP', 'UMWA MANAGED MEDICARE  IP', 'COVENTRY  IP', 'MEDIGOLD MANAGED MEDICARE  IP', 'MMO MANAGED MEDICARE  OP', '<Self-pay> IP', 'THE HEALTH PLAN  OP', 'SEORMC  OP', 'HEALTHLINK  OP', 'CARESOURCE MANAGED MEDICAID  OP', 'OHIO HEALTH CHOICE  IP', 'ANTHEM  OP', 'AETNA  IP', 'COFINITY  IP', 'HUMANA  IP', 'HUMANA MANAGED MEDICARE  IP', 'HEALTHREACH  IP', 'IHG  OP', 'Max IP', 'CARESOURCE MANAGED MEDICAID  IP', 'AETNA MANAGED MEDICARE  OP', 'FIRST HEALTH  IP', 'OHIO PREFERRED NETWORK  IP', 'PARAMOUNT MANAGED MEDICAID  IP', 'OHIOHEALTHY MEDICAL PLAN  IP', 'FIRST HEALTH  OP', 'COVENTRY  OP', 'CARESOURCE MANAGED MEDICARE  IP', 'AETNA MANAGED MEDICAID  IP', 'PARAMOUNT  IP', 'FLORA  OP', 'MOLINA MANAGED MEDICARE  IP', 'CARESOURCE MANAGED MEDICARE  OP', 'MOLINA MANAGED MEDICARE  OP', 'AETNA MANAGED MEDICARE  IP', 'FLORA  IP', 'OP Price', 'ANTHEM  IP', 'AHPO  IP', 'UHC  IP', 'OSU  IP', 'DEFINITY HEALTH  IP', 'HUMANA MANAGED MEDICARE  OP', 'MMO  IP', 'INHEALTH MUTUAL  OP', 'BEECHSTREET  IP', 'HEALTHLINK  IP', 'MEDIGOLD MANAGED MEDICARE  OP', 'HEALTHSMART  IP', 'MMO MANAGED MEDICARE  IP', 'CIGNA  IP', 'IHG  IP', 'OHIOHEALTHY MEDICAL PLAN  OP', 'Min IP', 'UHC MANAGED MEDICAID  OP', 'MANAGED MEDICAID  OP', 'Min OP', 'MOLINA MANAGED MEDICAID  IP', 'ANTHEM MANAGED MEDICARE  OP', 'Rev Code', 'IP Price', 'UMWA MANAGED MEDICARE  OP', 'PARAMOUNT  OP', 'AETNA  OP', 'OHIO HEALTH CHOICE  OP', 'SEORMC  IP', 'UHC MANAGED MEDICAID  IP', 'HUMANA  OP', 'BEECHSTREET  OP', 'THE HEALTH PLAN  IP', 'Procedure Description', 'HEALTHREACH  OP', 'COFINITY  OP', 'Quantity', 'AHPO  OP', 'BUCKEYE COMMUNITY PLAN  IP', 'MEDICARE PFFS  OP', 'EMERALD  OP', 'OSU  OP', 'GREATWEST  IP', 'Code Type', 'ANTHEM MANAGED MEDICARE  IP', 'BUCKEYE COMMUNITY PLAN  OP', 'Code', 'GREATWEST  OP', 'UHC MANAGED MEDICARE  OP', 'DEFINITY HEALTH  OP', 'MEDICARE PFFS  IP', 'AETNA MANAGED MEDICAID  OP', 'UHC MANAGED MEDICARE  IP', 'Max OP', 'CIGNA  OP', 'EMERALD  IP', 'OHIO PREFERRED NETWORK  OP', 'BUCKEYE MANAGED MEDICARE  OP', 'PARAMOUNT MANAGED MEDICAID  OP', 'INHEALTH MUTUAL  IP', '<Self-pay> OP'}
Key names in file 310536662_kettering-health-hamilton_standardcharges.json: {'license_information', 'financial_aid_policy', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'hospital_name'}
Key names in file 310537085_Anderson_StandardCharges.json: {'CARESOURCE OH MEDICAID [2002001] IP', 'UMR  [3113004] OP', 'MEDICAL MUTUAL PO BOX 6018 [3067006] IP', 'HUMANA CHOICE-PPO MEDICARE [101003] IP', 'MEDICARE PART A AND B [1001007] OP', 'CARESOURCE OH MEDICAID [2002001] OP', 'UHC MEDICARE COMPLETE [44] IP', 'UNITED HEALTHCARE - CHOICE PLU [3112014] OP', 'ANTHEM BCBS FEDERAL [3123012] IP', 'BCBS - OH PPO [3123016], BCBS OUT OF STATE [3123021] OP', 'UNITED HEALTHCARE - CHOICE PLU [3112014] IP', 'UHC MEDICARE COMPLETE [44] OP', 'HUMANA GOLD PLUS HMO [101001] OP', 'MEDIGOLD [4435001] OP', 'AETNA NAP CHOICE POS II [3004025] OP', 'UMR  [3113004] IP', 'Max IP', 'CIGNA [3020001] IP', 'MOLINA HEALTHCARE OHIO MEDICA [3070001] OP', 'CIGNA [3020001] OP', '<Self-pay> IP', 'AETNA MEDICARE-ADVANTAGE PPO [103002] IP', 'BCBS - OH PPO [3123016], BCBS OUT OF STATE [3123021] IP', 'MEDICARE PART A AND B [1001007] IP', 'HUMANA POS OPEN ACCESS  [
ETNA MANAGED MEDICAID  IP', 'PARAMOUNT  IP', 'FLORA  OP', 'MOLINA MANAGED MEDICARE  IP', 'CARESOURCE MANAGED MEDICARE  OP', 'MOLINA MANAGED MEDICARE  OP', 'AETNA MANAGED MEDICARE  IP', 'FLORA  IP', ' Max OP', 'ANTHEM  IP', 'AHPO  IP', 'UHC  IP', 'OSU  IP', 'DEFINITY HEALTH  IP', 'HUMANA MANAGED MEDICARE  OP', 'MMO  IP', ' Min OP', 'INHEALTH MUTUAL  OP', 'BEECHSTREET  IP', 'HEALTHLINK  IP', 'MEDIGOLD MANAGED MEDICARE  OP', 'HEALTHSMART  IP', 'MMO MANAGED MEDICARE  IP', 'CIGNA  IP', 'IHG  IP', 'OHIOHEALTHY MEDICAL PLAN  OP', 'UHC MANAGED MEDICAID  OP', 'MANAGED MEDICAID  OP', 'MOLINA MANAGED MEDICAID  IP', 'ANTHEM MANAGED MEDICARE  OP', 'UMWA MANAGED MEDICARE  OP', 'PARAMOUNT  OP', 'AETNA  OP', 'OHIO HEALTH CHOICE  OP', 'SEORMC  IP', 'UHC MANAGED MEDICAID  IP', 'HUMANA  OP', 'BEECHSTREET  OP', 'THE HEALTH PLAN  IP', 'HEALTHREACH  OP', 'COFINITY  OP', 'AHPO  OP', 'BUCKEYE COMMUNITY PLAN  IP', 'MEDICARE PFFS  OP', 'EMERALD  OP', 'OSU  OP', 'GREATWEST  IP', '<Self-pay> IP IP', 'ANTHEM MANAGED MEDICARE  IP', 'OP Price ', 'BUCKEYE COMMUNITY PLAN  OP', 'Rev Code ', 'GREATWEST  OP', 'UHC MANAGED MEDICARE  OP', 'DEFINITY HEALTH  OP', ' Max IP', 'MEDICARE PFFS  IP', 'AETNA MANAGED MEDICAID  OP', 'UHC MANAGED MEDICARE  IP', 'CIGNA  OP', 'EMERALD  IP', 'OHIO PREFERRED NETWORK  OP', 'BUCKEYE MANAGED MEDICARE  OP', 'PARAMOUNT MANAGED MEDICAID  OP', 'INHEALTH MUTUAL  IP', '<Self-pay> OP'}
Key names in file 34-1101385_mercer-county-joint-township-community-hospital_standardcharges.json: {'Inpatient Payer Specific Charge 16', 'Outpatient Payer Specific Charge 16', 'Outpatient Payer Specific Charge 18', 'Inpatient De-identified Maximum Negotiated Charge', 'Inpatient Payer Specific Charge 1', 'File Summary', 'Discounted Cash Pricing Policy', 'Inpatient Payer Specific Charge 3', 'Gross Charges', 'Outpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 4', 'Inpatient Payer Specific Charge 17', 'Outpatient Payer Specific Charge 5', 'Outpatient Payer Specific Charge 3', 'Outpatient Payer Specific Charge 10', 'Inpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 8', 'Outpatient Payer Specific Charge 20', 'Outpatient Payer Specific Charge 2', 'Inpatient Payer Specific Charge 7', 'Outpatient Payer Specific Charge 8', 'Outpatient Payer Specific Charge 15', 'Inpatient Payer Specific Charge 11', 'Inpatient Payer Specific Charge 14', 'Outpatient Payer Specific Charge 17', 'Outpatient Payer Specific Charge 19', 'Inpatient Payer Specific Charge 15', 'Professional Charges', 'Outpatient Payer Specific Charge 9', 'Inpatient Payer Specific Charge 2', 'Outpatient Payer Specific Charge 13', 'Outpatient Payer Specific Charge 6', 'Outpatient Payer Specific Charge 11', 'Outpatient De-identified Maximum Negotiated Charge', 'Inpatient De-identified Minimum Negotiated Charge', 'Outpatient Payer Specific Charge 12', 'Outpatient Payer Specific Charge 23', 'Inpatient Payer Specific Charge 13', 'Outpatient Payer Specific Charge 4', 'Inpatient Payer Specific Charge 6', 'Outpatient De-identified Minimum Negotiated Charge', 'Outpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge
[304002] IP', 'BWC FEDERAL ENERGY EMPLOYEES [711001] OP', 'MEDICARE AETNA HMO OR PPO [102001], MEDICARE AETNA HMO [102002], MEDICARE AETNA PPO [102003] OP', 'Min OP', 'BWC AULTCOMP [731001] OP', 'UHC [305001], UHC RIVER VALLEY [305002], UHC GENERIC [305003], UHC OPTIONS PPO [305004] OP', 'MOLINA [203001] IP', 'Rev Code', 'IP Price', 'BWC 3 HAB [726001] IP', 'MEDICARE ANTHEM HMO OR PPO [106001], MEDICARE ANTHEM SNP [106002] IP', 'MEDICARE ANTHEM HMO OR PPO [106001], MEDICARE ANTHEM SNP [106002] OP', 'MEDICARE MOLINA HMO PPO [112001] OP', 'MEDICARE MISC PFFS [108001] IP', 'HEALTHSMART [315001] IP', 'Procedure Description', 'BWC FEDERAL BLACK LUNG [729001] IP', 'TRICARE CHAMPUS [701001], TRICARE EAST REGION [701002], TRICARE WEST REGION [701003] OP', 'Quantity', 'BWC PROMEDICA MEDICAL MANAGEMENT [720001] IP', 'MEDICARE MOLINA HMO PPO [112001] IP', 'BWC PENDING MCO [709001] IP', 'BWC PREMIER MANAGED CARE [716001] OP', 'BWC GATES MCDONALD HEALTH PLUS [730001] OP', 'MEDICARE UHC HMO [105001] IP', 'MEDICARE MOUNT CARMEL HEALTH PLAN [107001] OP', 'BWC VANTAGE HEALTH PLAN [727001] IP', 'MMO [304001], MMO TRADITIONAL [304003] OP', 'Code Type', 'Effective Date', 'BWC PROMEDICA MEDICAL MANAGEMENT [720001] OP', 'Code', 'BWC UNIVERSITY COMPCARE [719001] IP', 'BWC 3 HAB [726001] OP', 'COPC SENIOR CARE ADVANTAGE [116001] IP', 'MEDICARE HEALTH PLN UPP OH VALLY [111001] IP', 'Min IP.1', 'MEDICARE AETNA HMO OR PPO [102001], MEDICARE AETNA HMO [102002], MEDICARE AETNA PPO [102003] IP', 'BWC AULTCOMP [731001] IP', 'PARAMOUNT ADVANTAGE [208001] IP', 'BWC COMP 1 [723001] IP', 'BWC THE HEALTH PLAN [728001] IP', 'BWC CAREWORKS OF OHIO INC [710001] OP', '<Self-pay> OP'}
Key names in file 344429941_Bluffton-Hospital_Standard-Charges.json: {'field23', 'field8', '344429941_Bluffton-Hospital_Standard-Charges', 'field21', 'field6', 'field26', 'field11', 'field19', 'field30', 'field10', 'field5', 'field12', 'field24', 'field31', 'field13', 'field28', 'field18', 'field9', 'field15', 'field29', 'field7', 'field22', 'field2', 'field4', 'field25', 'field17', 'field16', 'field3', 'field20', 'field27', 'field14'}
Key names in file 344434676_limamemorialhospital_standardcharges.json: {'additional_information', 'license_information', 'financial_aid_policy', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'hospital_name'}
Key names in file 344440884_wood-county-hospital_standardcharges.json: {'Name', 'Payer', 'GrossCharge', 'Charge', 'MaxNegotiatedCharge', 'Type', 'Code', 'Descr', 'QtyType', 'MinNegotiatedCharge', 'DiscountCashCharge'}
Key names in file 38-4105653_berger_standardcharges.json: {'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 21', 'Unnamed: 79', 'Unnamed: 76', 'Unnamed: 37', 'Unnamed: 77', 'Unnamed: 75', 'Unnamed: 72', 'Unnamed: 78', 'Unnamed: 65', 'Unnamed: 55', 'Unnamed: 29', 'Unnamed: 24', 'Unnamed: 22', 'Unnamed: 36', 'Unnamed: 16', 'Unnamed: 68', 'Unnamed: 23', 'Unnamed: 57', 'Unnamed: 31', 'Unnamed: 83', 'Unnamed: 60', 'Unnamed: 38', 'Unnamed: 6', 'Unnamed: 32', 'Unnamed: 51', 'Unnamed: 39', 'Unnamed: 33', 'Unnamed: 5', 'Unnamed: 71', 'Unnamed: 80', 'Unnamed: 69', 'Unnamed: 73', 'Unnamed: 63', 'Unnamed: 19', 'Unnamed: 1', 'Unnamed: 27', 'Unnamed: 44', 'Unnamed: 9', 'Unnamed: 41', 'Unnamed: 43', 'Unnamed: 28', 'Unnamed: 40', 'Unnamed: 4', 'Unnamed: 8', 'Unnamed: 82', 'Unnamed: 18', 'Unnamed: 17', 'Unnamed: 12', 'Unnamed: 67', 'Unnamed: 70', 'Unnamed: 11', 'Unnamed: 47', 'Unnamed: 84', 'Unnamed: 0', 'Unnamed: 35', 'Unnamed: 52', 'Unnamed: 64', 'Unnamed: 50', 'Unnamed: 45', 'Unnamed: 62', 'Unnamed: 66', 'Unnamed: 3', 'Unnamed: 34', 'Unnamed: 46', 'Unnamed: 49', 'Unnamed: 58', 'Unnamed: 74', 'Unnamed: 7', 'Unnamed: 42', 'Unnamed: 59', 'Unnamed: 53', 'Unnamed: 30', 'Unnamed: 61', 'Unnamed: 25', 'Unnamed: 56', 'Unnamed: 14', 'Unnamed: 48', 'Unnamed: 26', 'Unnamed: 2', 'Unnamed: 54', 'Unnamed: 10', 'Unnamed: 81', 'Unnamed: 20'}
Key names in file 453215312_king's-daughters-medical-center-ohio_standardcharges.json: {'lastUpdated', 'item'}
Key names in file 461382538_uh-portage-medical-center_standardcharges.json: {'lastUpdated', 'item'}
Key names in file 522085555_kindred-hospitals-dayton_standardcharges.json: {'Inpatient Payer Specific Charge 6', 'Inpatient Payer Specific Charge 10', 'Inpatient De-identified Maximum Negotiated Charge', 'Inpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 2', 'Inpatient Payer Specific Charge 5', 'Inpatient Payer Specific Charge 8', 'File Summary', 'Discounted Cash Pricing Policy', 'Inpatient Payer Specific Charge 3', 'Gross Charges', 'Inpatient De-identified Minimum Negotiated Charge', 'Inpatient Payer Specific Charge 4', 'Inpatient Payer Specific Charge 7', 'Inpatient Payer Specific Charge 9'}
Key names in file 752695684_kindred-hospital-lima_standardcharges.json: {'Inpatient Payer Specific Charge 6', 'Inpatient De-identified Maximum Negotiated Charge', 'Inpatient Payer Specific Charge 1', 'Inpatient Payer Specific Charge 2', 'Inpatient Payer Specific Charge 5', 'File Summary', 'Discounted Cash Pricing Policy', 'Inpatient Payer Specific Charge 3', 'Gross Charges', 'Inpatient De-identified Minimum Negotiated Charge', 'Inpatient Payer Specific Charge 4', 'Inpatient Payer Specific Charge 7'}
Key names in file 842771356_specialty-hospital-of-dayton_standardcharges.json: {'hospital_address', 'license_information', 'version', 'last_updated_on', 'hospital_location', 'standard_charge_information', 'affirmation', 'hospital_name'}
Key names in file 85-2985806_adena-fayette-medical-center_standardcharges.json: {'lastUpdated', 'item'}
Key names in file ChargeMaster010424.json: {'Outpatient All Items & Services', 'Inpatient'}
Key names in file Price-Transparency-Machine-Readable-03.16.2021-FINAL.json: {'Surg Hos @ Southwoods 2021'}
